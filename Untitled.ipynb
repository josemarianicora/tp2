# %%
rounds = [
    {
        'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
        'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
        'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
        'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
    {
        'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
        'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
        'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
        'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
        'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
    {
        'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
        'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
        'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
        'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
    {
        'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
        'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
        'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
        'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
    {
        'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
        'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
        'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
        'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
        'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]
shadowstats = {"kills": 0, "assists": 0, "deaths": 0, "mvps": 0, "puntos": 0}
blazestats = {"kills": 0, "assists": 0, "deaths": 0, "mvps": 0, "puntos": 0}
viperstats = {"kills": 0, "assists": 0, "deaths": 0, "mvps": 0, "puntos": 0}
froststats = {"kills": 0, "assists": 0, "deaths": 0, "mvps": 0, "puntos": 0}
reaperstats = {"kills": 0, "assists": 0, "deaths": 0, "mvps": 0, "puntos": 0}
maxpuntos = 0

for i in range(0,len(rounds)):
    shadowstats["kills"] = (shadowstats["kills"] + rounds[i]['Shadow']['kills'])
    shadowstats["assists"] = (shadowstats["assists"] + rounds[i]['Shadow']['assists'])
    if rounds[i]['Shadow']['deaths']:
        shadowstats["deaths"] = shadowstats["deaths"] + 1
    shadowpuntos = (rounds[i]['Shadow']['kills'] * 3) + rounds[i]['Shadow']['assists'] - rounds[i]['Shadow']['deaths']
    shadowstats["puntos"] = shadowstats["puntos"] + shadowpuntos
    
    blazestats["kills"] = (blazestats["kills"] + rounds[i]['Blaze']['kills'])
    blazestats["assists"] = (blazestats["assists"] + rounds[i]['Blaze']['assists'])
    if rounds[i]['Blaze']['deaths']:
        blazestats["deaths"] = blazestats["deaths"] + 1
    blazepuntos = (rounds[i]['Blaze']['kills'] * 3) + rounds[i]['Blaze']['assists'] - rounds[i]['Blaze']['deaths']
    blazestats["puntos"] = blazestats["puntos"] + blazepuntos
    
    viperstats["kills"] = (viperstats["kills"] + rounds[i]['Viper']['kills'])
    viperstats["assists"] = (viperstats["assists"] + rounds[i]['Viper']['assists'])
    if rounds[i]['Viper']['deaths']:
        viperstats["deaths"] = viperstats["deaths"] + 1
    viperpuntos = (rounds[i]['Viper']['kills'] * 3) + rounds[i]['Viper']['assists'] - rounds[i]['Viper']['deaths']
    viperstats["puntos"] = blazestats["puntos"] + blazepuntos
    
    froststats["kills"] = (froststats["kills"] + rounds[i]['Frost']['kills'])
    froststats["assists"] = (froststats["assists"] + rounds[i]['Frost']['assists'])
    if rounds[i]['Frost']['deaths']:
        froststats["deaths"] = froststats["deaths"] + 1
    frostpuntos = (rounds[i]['Frost']['kills'] * 3) + rounds[i]['Frost']['assists'] - rounds[i]['Frost']['deaths']
    froststats["puntos"] = froststats["puntos"] + frostpuntos
    
    reaperstats["kills"] = (reaperstats["kills"] + rounds[i]['Reaper']['kills'])
    reaperstats["assists"] = (reaperstats["assists"] + rounds[i]['Reaper']['assists'])
    if rounds[i]['Reaper']['deaths']:
        reaperstats["deaths"] = reaperstats["deaths"] + 1
    reaperpuntos = (rounds[i]['Reaper']['kills'] * 3) + rounds[i]['Reaper']['assists'] - rounds[i]['Reaper']['deaths']
    reaperstats["puntos"] = reaperstats["puntos"] + reaperpuntos

    if (shadowpuntos > blazepuntos) and (shadowpuntos > viperpuntos) and (shadowpuntos > frostpuntos) and (shadowpuntos > reaperpuntos):
        shadowstats["mvps"] = shadowstats["mvps"] + 1
        
    else:
        if blazepuntos > shadowpuntos and blazepuntos > viperpuntos and blazepuntos > frostpuntos and blazepuntos > reaperpuntos:
            blazestats["mvps"] = blazestats["mvps"] + 1
        else:
            if viperpuntos > shadowpuntos and viperpuntos > blazepuntos and viperpuntos > frostpuntos and viperpuntos > reaperpuntos:
                viperstats["mvps"] = viperstats["mvps"] + 1
            else:
                if frostpuntos > shadowpuntos and frostpuntos > blazepuntos and frostpuntos > viperpuntos and frostpuntos > reaperpuntos:
                    froststats["mvps"] = froststats["mvps"] + 1
                else:
                    reaperstats["mvps"] = reaperstats["mvps"] + 1
